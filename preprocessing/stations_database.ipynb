# %% [markdown]
# # Stations database
# The objective of stations database is to create a unique set of station-access combinations that is consistent for all years of observations. Some of the problems with the stations and access are: some stations have changed names, new access points are added or dropped, some stations have two unique ids (mostly to differentiate feeder entrances).
#
# When a data base of unique stations-access combanations is created, I will manually create a map that matches the station-access combination to a unique and consistent station ID. Additionally, stations will have walk, feeder and intercity access differentiated (Some stations have different IDs for feeder routes, but other stations have the same ID, but the difference can be made at the access point). This differentiation needs to be validated by Transmilenio because it is not always easy to infer it base on the access name.
#
# We dropped all DUAL stations (they only account for ~3.5% of the total transactions in the system)
#
# There are two cleaning procedures bacause files have different formats:
# 1. June 2015 to June 2018 (we previously created an "indent" column to differentiate the zone (indent 0), the station (indent 1), the access (indent 3) and the time (indent 4).
# 2. July 2018 to Present

# %%
import pandas as pd 
import numpy as np
import xlrd
import csv

import os
from os import listdir
import functools
import glob
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading files - raw data

# %%
## Read all files 
PATH = '../data/transactions'
all_files = []
for root,dirs,files in os.walk(PATH):
    for file in files:
        all_files.append(os.path.join(root, file))
        
## Files June 2015 to June 2017
files_2015 = list(filter(lambda f: f.endswith('.csv'), all_files))

#Files July 2017 to April 2021
years = '2017|2018|2019|2020|2021'
months = 'Enero-2017|Febrero-2017|Marzo-2017|Abril-2017|Mayo-2017|Junio-2017|~'
files_2017 = pd.Series(list(filter(lambda f: f.endswith('.xlsx'), all_files)))
files_2017 = files_2017[files_2017.str.contains(years)]
files_2017 = files_2017[~files_2017.str.contains(months)]

files = files_2015 + list(files_2017)
files = [files[0]] + files[3:] #Dropping Jun and July

# %%
# %%time 
raw_month = []
sheet = 'Validaciones Consolidado'
sheet = 'Validaciones Tullave'
for file in files:
    if file.endswith('.csv'):
        raw_month.append(pd.read_csv(file, header = 6))
    elif file.endswith('.xlsx'):
        condition = '2017|2018|Enero 2019|Febrero 2019'
        consolidado = pd.Series(file).str.contains(condition)[0]
        if consolidado:
            sheet = 'Validaciones Consolidado'
        else:
            sheet = 'Validaciones Tullave'

        raw_month.append(pd.read_excel(file, header = 6,sheet_name=sheet))
# Out:
# CPU times: user 22min 22s, sys: 10.9 s, total: 22min 33s
# Wall time: 22min 46s

# %%
# Import list of clean station that I had from previous reserach. 
# This stations only contain information of 2020. Data from previous 
# year is not consistent with this data. 

# This file can be found in https://github.com/jdcaicedo251/transmilenio-covid
stations_path = '../../../01_tm_covid/transmilenio-covid/data/input/stations.csv'
old_stations = pd.read_csv(stations_path)

# %% [markdown]
# ## Functions

# %%
#Classify zones in BRT or DUAL, depending to where they belong. 
stations_classification_dict = {'(11) Zona K Calle 26':'BRT', '(12) Zona L Carrera 10':'BRT',
       '(122) DUAL_M84 - C84':'DUAL', '(125) DUAL_K86 - M86':'DUAL', '(130) M82-L82':'DUAL',
       '(31) Zona F Av. Américas':'BRT', '(32) Zona C Av. Suba':'BRT','(35) Zona D Calle 80':'BRT',
       '(36) Zona A Caracas':'BRT', '(37) Zona J Eje Ambiental':'BRT', '(121) DUAL_M80_L80':'DUAL', 
       '(125) M86-K86':'DUAL', '(201) D81-H81':'DUAL', '(30) Zona G NQS Sur':'BRT', 
       '(33) Zona B AutoNorte':'BRT','(34) Zona H Caracas Sur':'BRT', '(38) Zona E NQS Central':'BRT',
       '(40) Zona T Ciudad Bolívar':'BRT','Total general':'Other', '(35101) /':'DUAL','(135) M81 - H81':'DUAL',
       '(30) Zona G NQS':'BRT', '(33) Zona B Norte':'BRT', '(34) Zona H Tunal': 'BRT', 'Dual D81-H81':'DUAL', 
       '(135) M81 - H81':'DUAL', '(135) M81-H81':'DUAL', '(34470)':'DUAL', '(135) H83-M83':'DUAL', 
       '(35882) /':'DUAL', '(23334) /':'DUAL', '(23757) /':'DUAL', '(35132) /':'DUAL' ,'(41444) /':'DUAL', 
       '(84)':'DUAL', '(07008) NQS - Calle 30 Sur':'BRT', '(39) Zona F Calle 13':'BRT', 
       '(252) D81-M81':'DUAL', '(253) H83-M83':'DUAL', '(201) Dual D81-H81':'DUAL', '(210) M80 - L80':'DUAL'}

# %%
def stations_data_base(df, classification, drop_brt = True):
    ''' Obtains unique combinations Station-Access. 
    Parameters: 
    ------------
    - df: raw transactions data 
    - classification: dict. Classifies zones in BRT and DUAL. Key: zone, value:'BRT'/'DUAL'/'Other'
                        -BRT: Zone is a BRT zone 
                        -DUAL: Zone is a Dual route
                        - Other: Zone is "Total general" (aggreage measure in the raw data)

    ------------
    Returns: transactions every 15 mins. Index is timestamp, columns are stations
    '''
    ### asserts 
    # classification stations are in df 
    # values in classifications are only DUAL or BRT or Other
    
    #For June 2015 to June 2018
    #note: Column indent was created by us manually in the raw excel file
    # to separate zone, station, access, and time. 
    if 'indent' in df.columns:
    
        time_indent = 3
        indent_level = {'zone':0, 'station':1, 'access':2}

        new_cols = ['zone', 'station','access']
        for key, value in indent_level.items(): 
            df[key] = df['indent']
            df[key] = df[key].where(df[key]!=value,df['Etiquetas de fila']).astype(str)
            df[key] = df[key].replace(to_replace = '^\\d', value =  np.nan, regex = True)\
                                .fillna(method = 'ffill')
        #Keep only time indent 
        df = df[df.indent == time_indent].drop(columns = ['indent','Total general'])
        df.rename(columns = {'Etiquetas de fila':'time'}, inplace = True)
     
    # For July 2018 to Present 
    else:
        
        renanme_cols = {'Línea':'zone','Estación':'station', 'Acceso de Estación':'access'}
        df = df[['Línea','Estación', 'Acceso de Estación']].rename(columns = renanme_cols)
        df.dropna(inplace = True)
        
    #Drop DUAL stations 
    ###########
    if drop_brt:
        
        df['type'] = df['zone'].replace(classification)
    
        #Make sure all zones have a classification
        non_existing_zones = df[~df.type.str.contains('BRT|DUAL|Other')]['zone']
        if non_existing_zones.shape[0] > 0:
            print(non_existing_zones.unique())

        df = df[df.type == 'BRT'].drop(columns = 'type')
        
    dates = df.columns[df.columns.str.contains(pat="\d", regex = True)]
    df['transactions'] = df[dates].replace(',','', regex=True).fillna(0).astype(int).sum(axis = 1)
        
    #Unique station-access pair 
    ##################
    df['station_access'] = df['station'] + '-' + df['access']
    df = df[['zone', 'station','access','station_access', 'transactions']]#.drop_duplicates(subset = 'station_access')
    
    return df

# %% [markdown]
# ## Understanding stations

# %%
df = raw_month[0]
nov = stations_data_base(df,stations_classification_dict, False)

stations = nov[['zone','station']]
stations = stations.drop_duplicates()

# %%
unique_zones = stations.zone.nunique()
unique_stations = stations.station.nunique()
print ('There are', unique_zones, 'unique zones')
print ('There are', unique_stations, 'unique stations')
# Out:
# There are 18 unique zones
# There are 186 unique stations

# %%
#Zones
counter = 1
for zone in stations.zone.unique():
    print('ZONE:', counter)
    df = stations[stations.zone == zone]
    print ('Number of stations',df.shape[0])
    print (df)
    print ('')
    counter += 1
# Out:
# ZONE: 1
# Number of stations 14
#                       zone                         station
# 3     (11) Zona K Calle 26         (06000) Portal Eldorado
# 327   (11) Zona K Calle 26                 (06001) Modelia
# 405   (11) Zona K Calle 26               (06002) Normandía
# 486   (11) Zona K Calle 26               (06100) Av. Rojas
# 565   (11) Zona K Calle 26               (06101) El Tiempo
# 645   (11) Zona K Calle 26        (06102) Salitre El Greco
# 728   (11) Zona K Calle 26                     (06103) CAN
# 809   (11) Zona K Calle 26             (06104) Gobernación
# 890   (11) Zona K Calle 26          (06105) Quinta Paredes
# 968   (11) Zona K Calle 26               (06106) Corferias
# 1050  (11) Zona K Calle 26    (06107) Ciudad Universitaria
# 1210  (11) Zona K Calle 26  (06108) Plaza de la Democracia
# 1289  (11) Zona K Calle 26          (06109) Centro Memoria
# 1449  (11) Zona K Calle 26           (06111) Universidades
#
# ZONE: 2
# Number of stations 11
#                         zone                      station
# 1528  (12) Zona L Carrera 10   (10000) Portal 20 de Julio
# 1847  (12) Zona L Carrera 10          (10001) Country Sur
# 2008  (12) Zona L Carrera 10  (10002) Av. Primero de Mayo
# 2169  (12) Zona L Carrera 10        (10003) Ciudad Jardín
# 2250  (12) Zona L Carrera 10            (10004) Policarpa
# 2407  (12) Zona L Carrera 10         (10005) Bicentenario
# 2832  (12) Zona L Carrera 10        (10006) San Victorino
# 2988  (12) Zona L Carrera 10           (10007) Las Nieves
# 3146  (12) Zona L Carrera 10            (10008) San Diego
# 3377  (12) Zona L Carrera 10       (10009) Museo Nacional
# 3535  (12) Zona L Carrera 10           (10010) Hospitales
#
# ZONE: 3
# Number of stations 4
#                       zone             station
# 3699  (122) DUAL_M84 - C84    (490) M84 Normal
# 4593  (122) DUAL_M84 - C84    (491) C84 Normal
# 5385  (122) DUAL_M84 - C84  (492) M84 Ciclovía
# 5783  (122) DUAL_M84 - C84  (493) C84 Ciclovía
#
# ZONE: 4
# Number of stations 7
#                        zone                                 station
# 6096   (125) DUAL_K86 - M86           (310) M86-K86 Refuerzo Portal
# 6468   (125) DUAL_K86 - M86  (328) M86-K86 Refuerzo Portal Ciclovia
# 6579   (125) DUAL_K86 - M86                    (497) Refuerzo Museo
# 6590   (125) DUAL_K86 - M86                  (505) M86-K86 Ciclovia
# 7340   (125) DUAL_K86 - M86                    (506) M86-K86 Normal
# 7359   (125) DUAL_K86 - M86                    (606) M86-K86 Normal
# 10192  (125) DUAL_K86 - M86                (607) K86 Refuerzo CL 75
#
# ZONE: 5
# Number of stations 6
#                 zone                               station
# 10567  (130) M82-L82   (405) M82-L82 Refuerzo Bicentenario
# 10572  (130) M82-L82                  (597) M82-L82 Normal
# 12795  (130) M82-L82            (598) M82-L82 Refuerzo ida
# 12875  (130) M82-L82         (599) M82-L82 Refuerzo vuelta
# 13036  (130) M82-L82  (600) M82-L82 Refuerzo Av 1a de Mayo
# 13613  (130) M82-L82              (601) L82 Refuerzo CL 79
#
# ZONE: 6
# Number of stations 10
#                            zone                      station
# 13771  (31) Zona F Av. Américas      (05000) Portal Américas
# 14569  (31) Zona F Av. Américas  (05100) Banderas P. Central
# 15132  (31) Zona F Av. Américas     (05101) Mandalay - Cr.73
# 15216  (31) Zona F Av. Américas       (05102) Mundo Aventura
# 15301  (31) Zona F Av. Américas             (05103) Marsella
# 15384  (31) Zona F Av. Américas              (05105) Pradera
# 15467  (31) Zona F Av. Américas     (05107) Américas - Cr.53
# 15549  (31) Zona F Av. Américas         (05001) Patio Bonito
# 15714  (31) Zona F Av. Américas               (05002) Tintal
# 15881  (31) Zona F Av. Américas       (05005) Transversal 86
#
# ZONE: 7
# Number of stations 14
#                        zone                    station
# 15964  (32) Zona C Av. Suba        (03000) Portal Suba
# 16661  (32) Zona C Av. Suba       (03010) PUENTE LARGO
# 16742  (32) Zona C Av. Suba   (03011) SUBA - CALLE 100
# 16824  (32) Zona C Av. Suba    (03012) SUBA - CALLE 95
# 16905  (32) Zona C Av. Suba          (03013) RIO NEGRO
# 16986  (32) Zona C Av. Suba         (03014) SAN MARTIN
# 17067  (32) Zona C Av. Suba         (03001) LA CAMPIÑA
# 17150  (32) Zona C Av. Suba  (03005) SUBA - AV. BOYACA
# 17312  (32) Zona C Av. Suba      (03002) SUBA - TV- 91
# 17395  (32) Zona C Av. Suba         (03003) 21 ANGELES
# 17480  (32) Zona C Av. Suba   (03006) NIZA - CALLE 127
# 17646  (32) Zona C Av. Suba              (03009) SHAIO
# 17728  (32) Zona C Av. Suba    (03007) HUMEDAL CORDOBA
# 17809  (32) Zona C Av. Suba          (03004) GRATAMIRA
#
# ZONE: 8
# Number of stations 16
#                        zone                                station
# 17890  (35) Zona D Calle 80              (04000) Cabecera Calle 80
# 18517  (35) Zona D Calle 80                     (04104) Avenida 68
# 18599  (35) Zona D Calle 80                     (04105) Carrera 53
# 18678  (35) Zona D Calle 80                     (04106) Carrera 47
# 18759  (35) Zona D Calle 80                (04107) Escuela Militar
# 18841  (35) Zona D Calle 80                        (04108) El Polo
# 18923  (35) Zona D Calle 80                       (04001) Quirigua
# 19004  (35) Zona D Calle 80                     (04002) Carrera 90
# 19085  (35) Zona D Calle 80                 (04101) Minuto de Dios
# 19168  (35) Zona D Calle 80                 (04102) Avenida Boyaca
# 19251  (35) Zona D Calle 80                     (04103) Las Ferias
# 19333  (35) Zona D Calle 80                      (04004) La Granja
# 19415  (35) Zona D Calle 80                     (04100) Carrera 77
# 19496  (35) Zona D Calle 80              (50006) Corral Carrera 77
# 19647  (35) Zona D Calle 80         (04003) Avenida Ciudad de Cali
# 19729  (35) Zona D Calle 80  (50004) Corral Avenida Ciudad de Cali
#
# ZONE: 9
# Number of stations 12
#                       zone             station
# 19805  (36) Zona A Caracas    (09111) Calle 19
# 19967  (36) Zona A Caracas    (09113) Calle 22
# 20131  (36) Zona A Caracas  (09115) Profamilia
# 20292  (36) Zona A Caracas    (09114) Calle 26
# 20453  (36) Zona A Caracas  (09116) Avenida 39
# 20613  (36) Zona A Caracas  (09121) Las Flores
# 20774  (36) Zona A Caracas    (09122) Calle 72
# 20935  (36) Zona A Caracas    (09119) Calle 57
# 21096  (36) Zona A Caracas    (09123) Calle 76
# 21259  (36) Zona A Caracas    (09117) Calle 45
# 21420  (36) Zona A Caracas       (09118) Marly
# 21580  (36) Zona A Caracas    (09120) Calle 63
#
# ZONE: 10
# Number of stations 3
#                             zone                  station
# 21742  (37) Zona J Eje Ambiental  (09110) Avenida Jimenez
# 21987  (37) Zona J Eje Ambiental    (14004) Museo del Oro
# 22105  (37) Zona J Eje Ambiental        (14005) Las Aguas
#
# ZONE: 11
# Number of stations 9
#                      zone                                   station
# 22258  (121) DUAL_M80_L80             (305) M80-L80 Refuerzo vuelta
# 22462  (121) DUAL_M80_L80         (306) M80-L80 Refuerzo Reversible
# 22465  (121) DUAL_M80_L80  (340) M80-L80 Refuerzo Museo-20 de Julio
# 22536  (121) DUAL_M80_L80                      (400) M80-L80 Normal
# 25845  (121) DUAL_M80_L80                (402) M80-L80 Refuerzo ida
# 26042  (121) DUAL_M80_L80                    (507) M80-L80 Ciclovia
# 27322  (121) DUAL_M80_L80               (517) L80 Refuerzo Ciclovía
# 27527  (121) DUAL_M80_L80                  (546) L80 Refuerzo CL 79
# 27833  (121) DUAL_M80_L80                  (475) L80  VUELTA NORMAL
#
# ZONE: 12
# Number of stations 6
#                 zone                                 station
# 27837  (125) M86-K86           (310) M86-K86 Refuerzo Portal
# 27885  (125) M86-K86  (328) M86-K86 Refuerzo Portal Ciclovia
# 27894  (125) M86-K86                  (505) M86-K86 Ciclovia
# 28430  (125) M86-K86                    (506) M86-K86 Normal
# 28451  (125) M86-K86                    (606) M86-K86 Normal
# 30307  (125) M86-K86                (607) K86 Refuerzo CL 75
#
# ZONE: 13
# Number of stations 7
#                 zone                   station
# 30390  (201) D81-H81          (533) D81 Normal
# 31590  (201) D81-H81          (534) H81 Normal
# 33040  (201) D81-H81  (540) D81 Refuerzo Museo
# 33059  (201) D81-H81  (541) H81 Refuerzo Museo
# 33112  (201) D81-H81        (553) D81 Ciclovia
# 33472  (201) D81-H81        (554) H81 Ciclovia
# 33907  (201) D81-H81  (628) D81 Refuerzo CL 57
#
# ZONE: 14
# Number of stations 17
#                       zone                           station
# 34092  (30) Zona G NQS Sur                (07000) Portal Sur
# 34569  (30) Zona G NQS Sur         (07006) General Santander
# 34813  (30) Zona G NQS Sur                      (07009) SENA
# 34896  (30) Zona G NQS Sur              (07113) SANTA ISABEL
# 34979  (30) Zona G NQS Sur                   (07001) PERDOMO
# 35063  (30) Zona G NQS Sur                   (07004) VENECIA
# 35148  (30) Zona G NQS Sur       (07007) NQS - Calle 38A Sur
# 35233  (30) Zona G NQS Sur                  (07002) MADELENA
# 35317  (30) Zona G NQS Sur                 (07003) SEVILLANA
# 35400  (30) Zona G NQS Sur                  (07005) ALQUERIA
# 35484  (30) Zona G NQS Sur        (07008) NQS - Calle 30 Sur
# 35565  (30) Zona G NQS Sur                 (07503) SAN MATEO
# 35646  (30) Zona G NQS Sur                  (07504) TERREROS
# 35727  (30) Zona G NQS Sur                 (07505) LEON XIII
# 35808  (30) Zona G NQS Sur                  (07506) DESPENSA
# 35890  (30) Zona G NQS Sur                 (07112) COMUNEROS
# 36052  (30) Zona G NQS Sur  (50007) Corral General Santander
#
# ZONE: 15
# Number of stations 17
#                         zone                            station
# 36199  (33) Zona B AutoNorte   (02000) Cabecera Autopista Norte
# 36963  (33) Zona B AutoNorte                  (02105) Calle 142
# 37122  (33) Zona B AutoNorte                     (02200) Alcalá
# 37286  (33) Zona B AutoNorte                     (02304) Heroes
# 37370  (33) Zona B AutoNorte                  (02104) Calle 146
# 37453  (33) Zona B AutoNorte                  (02202) Calle 127
# 37534  (33) Zona B AutoNorte                     (02302) Virrey
# 37616  (33) Zona B AutoNorte                    (02103) Mazurén
# 37772  (33) Zona B AutoNorte                (02204) Pepe Sierra
# 37853  (33) Zona B AutoNorte                  (02300) Calle 100
# 38013  (33) Zona B AutoNorte                    (02101) Toberín
# 38091  (33) Zona B AutoNorte                      (02201) Prado
# 38172  (33) Zona B AutoNorte                  (02205) Calle 106
# 38253  (33) Zona B AutoNorte            (02102) Cardio Infantíl
# 38407  (33) Zona B AutoNorte                   (02303) Calle 85
# 38489  (33) Zona B AutoNorte  (02001) Centro Comercial Santa Fe
# 38567  (33) Zona B AutoNorte                   (02502) Terminal
#
# ZONE: 16
# Number of stations 19
#                           zone                      station
# 38646  (34) Zona H Caracas Sur         (08000) Portal Tunal
# 38892  (34) Zona H Caracas Sur      (08001) Parque el Tunal
# 39049  (34) Zona H Caracas Sur           (08002) Biblioteca
# 39207  (34) Zona H Caracas Sur        (09000) Cabecera Usme
# 39701  (34) Zona H Caracas Sur             (09002) Consuelo
# 39782  (34) Zona H Caracas Sur              (09003) Socorro
# 39867  (34) Zona H Caracas Sur          (09004) Santa Lucía
# 40036  (34) Zona H Caracas Sur              (09101) Quiroga
# 40120  (34) Zona H Caracas Sur                (09103) Olaya
# 40205  (34) Zona H Caracas Sur             (09104) Restrepo
# 40368  (34) Zona H Caracas Sur            (09105) Río Fucha
# 40451  (34) Zona H Caracas Sur       (09109) Tercer Milenio
# 40612  (34) Zona H Caracas Sur               (09106) Nariño
# 40695  (34) Zona H Caracas Sur               (09107) Hortúa
# 40859  (34) Zona H Caracas Sur             (09108) Hospital
# 40941  (34) Zona H Caracas Sur              (09001) Molinos
# 41110  (34) Zona H Caracas Sur         (09100) Calle 40 Sur
# 41278  (34) Zona H Caracas Sur  (50002) Corral Calle 40 Sur
# 41396  (34) Zona H Caracas Sur       (50003) Corral Molinos
#
# ZONE: 17
# Number of stations 13
#                           zone                     station
# 41476  (38) Zona E NQS Central          (07101) CASTELLANA
# 41582  (38) Zona E NQS Central      (07102) NQS - CALLE 75
# 41662  (38) Zona E NQS Central           (07103) AV. CHILE
# 41821  (38) Zona E NQS Central       (07104) Simon Bolivar
# 41901  (38) Zona E NQS Central             (07105) COLISEO
# 41982  (38) Zona E NQS Central           (07106) EL CAMPIN
# 42142  (38) Zona E NQS Central         (07107) U. NACIONAL
# 42302  (38) Zona E NQS Central       (07108) Av. El Dorado
# 42460  (38) Zona E NQS Central                 (07109) CAD
# 42620  (38) Zona E NQS Central          (07110) PALOQUEMAO
# 42701  (38) Zona E NQS Central      (07111) NQS - RICAURTE
# 42866  (38) Zona E NQS Central  (07201) Guatoque -Veraguas
# 42944  (38) Zona E NQS Central      (07200) Tygua-San José
#
# ZONE: 18
# Number of stations 7
#                        zone                   station
# 43248  (39) Zona F Calle 13     (12000) Puente Aranda
# 43331  (39) Zona F Calle 13        (12001) Carrera 43
# 43490  (39) Zona F Calle 13  (12002) CDS - Carrera 32
# 43694  (39) Zona F Calle 13          (12003) Ricaurte
# 43776  (39) Zona F Calle 13        (12004) Carrera 22
# 43936  (39) Zona F Calle 13   (12007) Zona Industrial
# 44099  (39) Zona F Calle 13         (14001) La Sabana

# %%
# stations_classification_dict = {'(11) Zona K Calle 26':'BRT', '(12) Zona L Carrera 10':'BRT',
#        '(122) DUAL_M84 - C84':'DUAL', '(125) DUAL_K86 - M86':'DUAL', '(130) M82-L82':'DUAL',
#        '(31) Zona F Av. Américas':'BRT', '(32) Zona C Av. Suba':'BRT',
#        '(35) Zona D Calle 80':'BRT', '(36) Zona A Caracas':'BRT',
#        '(37) Zona J Eje Ambiental':'BRT', '(121) DUAL_M80_L80':'DUAL', '(125) M86-K86':'DUAL',
#        '(201) D81-H81':'DUAL', '(30) Zona G NQS Sur':'BRT', '(33) Zona B AutoNorte':'BRT',
#        '(34) Zona H Caracas Sur':'BRT', '(38) Zona E NQS Central':'BRT',
#        '(39) Zona F Calle 13':'BRT'}

nov['type'] = nov['zone'].replace(stations_classification_dict)
summary_brt_dual = nov.groupby('type').agg({'transactions':'sum'})
summary_brt_dual['total'] = summary_brt_dual['transactions'].sum()
summary_brt_dual['pct'] = summary_brt_dual['transactions']/summary_brt_dual['total']

print ('% of BRT Transactions: {:.2f}'.format(summary_brt_dual['pct'][0]*100))
print ('% of DUAL Transactions: {:.2f}'.format(summary_brt_dual['pct'][1]*100))
# Out:
# % of BRT Transactions: 96.56
# % of DUAL Transactions: 3.44

# %% [markdown]
# ## Create final stations database

# %%
raw_stations = []
for month in raw_month:
    df = stations_data_base(month, stations_classification_dict, True)
    raw_stations.append(df)

# %% [markdown]
# ### Some facts about this dataset

# %%
stations_database = pd.concat(raw_stations, axis = 0).drop_duplicates(subset = 'station_access') 
# I should have drop duplicates in the colum "station_access". I had dropthem manually. 
print ('There are {} unique station-access combination in the observed data'.format(stations_database.shape[0]))
# Out:
# There are 991 unique station-access combination in the observed data

# %%
# Unique station-access combination 
old_stations['station_access'] = old_stations['nombreestacion'] + '-' + old_stations['nombreaccesoestacion']

#Merge to check for matches 
merge = old_stations.merge(stations_database, how = 'outer', on = 'station_access')

missing_combination = merge[merge.nombrelinea.isnull()].shape[0]
stations_not_found = merge[merge.zone.isnull()].shape[0]
print ('There are {} additional combinations in our dataset'.format(missing_combination))
print ('There are {} additional combinations in old dataset '.format(stations_not_found))
# Out:
# There are 420 additional combinations in our dataset
# There are 23 additional combinations in old dataset

# %%
merge.to_csv('../data/stations_database_v2.csv', index = False)

# %% [markdown]
# At this point, I manually checked that all addtional stations match to an existing station. I have also:
# - Drop all duplicates for station_access combination. There are some station for which the zone had a different name, therefore the observation was not dropped before. This resulted in duplicated transaction when matching stations and access.
# - Ricaurte and Avenida Jimenez belong to two zones each. For the purpose of prediction, I have joined the demand for each station.
